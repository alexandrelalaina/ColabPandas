# %%
# importacao do Pandas e use como pd
import pandas as pd

#df = DataFrame, onde contem linhas e colunas
# param error_bad_lines => ignorar linhas com erros
# param sep             => qual sera o separador, por Default é ,(virgula)
df = pd.read_csv("/content/drive/MyDrive/Datasets/Gapminder.csv", error_bad_lines=False, sep=";")

# %%
# Visualizando as 5 primeiras linhas

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={"country":"País", "continent":"continente","year":"ano", "lifeExp":"Expectativa de vida", "pop":"Pop Total", "gdpPercap":"PIB"})

# %%
# retorna qtd de linhas e colunas
df.shape

# %%
# retorna o tipo dos dados
df.dtypes
# Out:
# País                    object
# Continente              object
# ano                      int64
# Expectativa de vida    float64
# Pop Total                int64
# PIB                    float64
# dtype: object

# %%
# retorna info estatisticas
df.describe()
# Out:
#                ano  Expectativa de vida     Pop Total            PIB
# count  3312.000000          3312.000000  3.312000e+03    3312.000000
# mean   1980.301630            65.246871  3.161489e+07   11317.115805
# std      16.927294            11.768412  1.041193e+08   11369.142739
# min    1950.000000            23.599000  5.941200e+04     241.165877
# 25%    1967.000000            58.337500  2.678572e+06    2514.625266
# 50%    1982.000000            69.610000  7.557218e+06    7838.505123
# 75%    1996.000000            73.657750  1.958522e+07   17357.879170
# max    2007.000000            82.670000  1.318683e+09  113523.132900

# %%
# distinct
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
# loc = localizacao
oceania = df.loc[ df["Continente"] == "Oceania" ]
oceania["Continente"].unique()
# Out:
# array(['Oceania'], dtype=object)

# %%
# group by por coluna
df.groupby("Continente") ["País"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: País, dtype: int64

# %%
# media de exp. de vida por ano
df.groupby("ano")["Expectativa de vida"].mean()
# Out:
# ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# 1999    75.703636
# 2000    76.026364
# 2001    76.257879
# 2002    66.835695
# 2003    76.586667
# 2004    76.921563
# 2005    76.718667
# 2006    77.887778
# 2007    67.868557
# Name: Expectativa de vida, dtype: float64

# %%
df["PIB"].sum()
# Out:
# 37482287.5451553
